# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import scipy.stats as stat

pd.pandas.set_option('display.max_columns', None)

# %%
data = pd.read_csv('train.csv')

print(data.shape)

data.head(7)
# Out:
# (1460, 81)
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# ...

# %%
# drop id column since it not neccessary

data.drop('Id', axis=1, inplace=True)

data.head(2)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# 0       Norm     1Fam     2Story            7            5       2003
# 1       Norm     1Fam     1Story            6            8       1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# 0          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 1          1976     Gable  CompShg     MetalSd     MetalSd       None
#
#    MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# ...

# %% [markdown]
# ### Analysis
#
# The following analysis will be
# 1. Target Variable
# 2. Handling Missing data
# 3. Variable Types
# 4. Categorical variable
# 5. Numerical variables

# %% [markdown]
# Explore Target Variable Distribution

# %%
data['SalePrice'].hist(bins=50, density=True)
plt.ylabel('Number of houses')
plt.xlabel('Sale Price')
plt.show()

# %% [markdown]
# We see that the target variable is not a Guassian distribution, we use Logarithmic transformation to transform the data into a Guassian Distribution

# %%
np.log(data['SalePrice']).hist(bins=50, density=True)
plt.ylabel('Number of houses')
plt.xlabel('Sale Price')
plt.show()

# %% [markdown]
# ## Variable Type

# %%
cat_var = [var for var in data.columns if data[var].dtype == 'O']

# %%
print(cat_var)
len(cat_var)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']
# 43

# %% [markdown]
# MSSubClass althought is numerical variable, but from the data description each number that describes the Identifies the type of dwelling involved in the sale.
#
# So, it will be added to the list of categorical variable

# %%
cat_var = cat_var + ['MSSubClass']

print(cat_var)
len(cat_var)
# Out:
# ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition', 'MSSubClass']
# 44

# %%
# cast all cat_var variables as categorical

data[cat_var] = data[cat_var].astype('O')

# %% [markdown]
# ### Numerical Variable

# %%
num_vars = [
    var for var in data.columns if var not in cat_var and var != 'SalePrice'
]

print(num_vars)
len(num_vars)
# Out:
# ['LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']
# 35

# %% [markdown]
# ### Handling Missing Values

# %%
null_vars = [
    col for col in data.columns if data[col].isnull().sum() > 0
]

data[null_vars].isnull().mean().sort_values(ascending=False)
# Out:
# PoolQC          0.995205
# MiscFeature     0.963014
# Alley           0.937671
# Fence           0.807534
# FireplaceQu     0.472603
# LotFrontage     0.177397
# GarageType      0.055479
# GarageYrBlt     0.055479
# GarageFinish    0.055479
# GarageQual      0.055479
# GarageCond      0.055479
# BsmtExposure    0.026027
# BsmtFinType2    0.026027
# BsmtFinType1    0.025342
# BsmtCond        0.025342
# BsmtQual        0.025342
# MasVnrArea      0.005479
# MasVnrType      0.005479
# Electrical      0.000685
# dtype: float64

# %%
data[null_vars].isnull().mean().sort_values(
    ascending=False
).plot.bar(figsize=(10, 4))
plt.ylabel('Percentage of missing data')
plt.axhline(
    y=0.90, color='r', linestyle='-'
)
plt.axhline(
    y=0.80, color='g',linestyle='-'
)

plt.axhline(
    y=0.70, color='y', linestyle='-'
)

# %% [markdown]
# From the graph above only 3 of the features cross `90% missing value mark` with 4 features cross `70% missing value mark`

# %%
cat_na = [
    var for var in cat_var if var in null_vars
]

num_na = [
    var for var in num_vars if var in null_vars
]

print('Number of categorical variable with na', len(cat_na))
print('Number of numerical variables with na', len(num_na))
# Out:
# Number of categorical variable with na 16
# Number of numerical variables with na 3

# %%
num_na
# Out:
# ['LotFrontage', 'MasVnrArea', 'GarageYrBlt']

# %%
cat_na
# Out:
# ['Alley',
#  'MasVnrType',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinType2',
#  'Electrical',
#  'FireplaceQu',
#  'GarageType',
#  'GarageFinish',
#  'GarageQual',
#  'GarageCond',
#  'PoolQC',
#  'Fence',
#  'MiscFeature']

# %% [markdown]
# ### Relationship between missing data and Sale Price
#
# The plot below will show the relationship house price and features with missing data

# %%
def analyse_na_value(df, var):

    df = df.copy()

    df[var] = np.where(df[var].isnull(), 1, 0)

    tmp = df.groupby(var)['SalePrice'].agg(['mean', 'std'])

    tmp.plot(
        kind='barh',
        y='mean',
        legend = False,
        xerr ='std',
        title = 'Sale Price',
        color = 'g'
    )

    plt.show()

# %%
data
# Out:
#      MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0            60       RL         65.0     8450   Pave   NaN      Reg
# 1            20       RL         80.0     9600   Pave   NaN      Reg
# 2            60       RL         68.0    11250   Pave   NaN      IR1
# 3            70       RL         60.0     9550   Pave   NaN      IR1
# 4            60       RL         84.0    14260   Pave   NaN      IR1
# ...         ...      ...          ...      ...    ...   ...      ...
# 1455         60       RL         62.0     7917   Pave   NaN      Reg
# 1456         20       RL         85.0    13175   Pave   NaN      Reg
# 1457         70       RL         66.0     9042   Pave   NaN      Reg
# 1458         20       RL         68.0     9717   Pave   NaN      Reg
# 1459         20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# ...

# %%
for var in null_vars:
    analyse_na_value(data, var)
# Out:
# /home/arnold/Desktop/MlOp/env/lib/python3.8/site-packages/numpy/core/_methods.py:44: RuntimeWarning: invalid value encountered in reduce
#   return umr_minimum(a, axis, None, out, keepdims, initial, where)
# /home/arnold/Desktop/MlOp/env/lib/python3.8/site-packages/numpy/core/_methods.py:40: RuntimeWarning: invalid value encountered in reduce
#   return umr_maximum(a, axis, None, out, keepdims, initial, where)

# %% [markdown]
# ### Numerical Variables
#
# Now let's explore the numerical variables

# %%
print('Number of numerical variables: ', len(num_vars))

data[num_vars].head(7)
# Out:
# Number of numerical variables:  35
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
# 5         85.0    14115            5            5       1993          1995
# 6         75.0    10084            8            5       2004          2005
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  1stFlrSF  \
# 0       196.0         706           0        150          856       856
# 1         0.0         978           0        284         1262      1262
# 2       162.0         486           0        434          920       920
# ...

# %% [markdown]
# ### Tempooral variables (Year variable)
#
# There are 4 temporal variables `'YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold'`

# %%
year_vars = [
    var for var in num_vars if 'Yr' in var or 'Year' in var
]

year_vars
# Out:
# ['YearBuilt', 'YearRemodAdd', 'GarageYrBlt', 'YrSold']

# %%
# let get unique counts for each of the year variable

for var in year_vars:
    print(var, data[var].unique())
    print('===================================================================')
    print(var, data[var].nunique())
# Out:
# YearBuilt [2003 1976 2001 1915 2000 1993 2004 1973 1931 1939 1965 2005 1962 2006
#  1960 1929 1970 1967 1958 1930 2002 1968 2007 1951 1957 1927 1920 1966
#  1959 1994 1954 1953 1955 1983 1975 1997 1934 1963 1981 1964 1999 1972
#  1921 1945 1982 1998 1956 1948 1910 1995 1991 2009 1950 1961 1977 1985
#  1979 1885 1919 1990 1969 1935 1988 1971 1952 1936 1923 1924 1984 1926
#  1940 1941 1987 1986 2008 1908 1892 1916 1932 1918 1912 1947 1925 1900
#  1980 1989 1992 1949 1880 1928 1978 1922 1996 2010 1946 1913 1937 1942
#  1938 1974 1893 1914 1906 1890 1898 1904 1882 1875 1911 1917 1872 1905]
# ...
# YearBuilt 112
# YearRemodAdd [2003 1976 2002 1970 2000 1995 2005 1973 1950 1965 2006 1962 2007 1960
#  2001 1967 2004 2008 1997 1959 1990 1955 1983 1980 1966 1963 1987 1964
#  1972 1996 1998 1989 1953 1956 1968 1981 1992 2009 1982 1961 1993 1999
#  1985 1979 1977 1969 1958 1991 1971 1952 1975 2010 1984 1986 1994 1988
#  1954 1957 1951 1978 1974]
# ...
# YearRemodAdd 61
# ...

# %%
data.groupby('YrSold')['SalePrice'].median().plot()
plt.ylabel('Median House Price')
# Out:
# Text(0, 0.5, 'Median House Price')

# %% [markdown]
# House price seems to decrease as the year of the year increase. Younger houses seems to be more expensive than older house

# %%
data.groupby('YearBuilt')['SalePrice'].median().plot()
plt.ylabel('Median House Price')
# Out:
# Text(0, 0.5, 'Median House Price')

# %% [markdown]
# House built in earlier years seems to be more expensive
#
# Let's explore further

# %%
def analyse_year_vars(df, var):

    df = df.copy()

    df[var] = df['YrSold'] - df[var]

    df.groupby('YrSold')[var].median().plot()
    plt.ylabel('Time from ' + var)
    plt.show()


for var in year_vars:
    if var != 'YrSold':
        analyse_year_vars(data, var)

# %% [markdown]
# We see from the plots above that most houses very old garage age from 2007 to 2010 with 32 years been the highest garage age and 27 years being highest age in which a house was remodelled

# %%
def analyse_year_vars(df, var):


    df = df.copy()

    df[var] = df['YrSold'] -df[var]

    plt.scatter(df[var], df['SalePrice'])
    plt.ylabel('SalePrice')
    plt.xlabel(var)
    plt.show()

for var in year_vars:
    if var != 'YrSold':
        analyse_year_vars(data,var)

# %% [markdown]
# From the plots above there is an inverse relationship between the year was remodelled, garage age and year built.
#
# This makes sense, as the older a house the more repair it will need and less the price bid

# %% [markdown]
# ### Discrete Variables
#
# Discrete variables are those variable that show finite number od value counts. Here, I am assuming that any variable in which the number od discrete variables is 20 is discrete

# %%
discrete_vars = [
    var for var in num_vars if len(
        data[var].unique() 
    ) < 20 and var not in year_vars
]

print('Number of discrete variables are', len(discrete_vars))
# Out:
# Number of discrete variables are 13

# %%
data[discrete_vars].head(3)
# Out:
#    OverallQual  OverallCond  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  \
# 0            7            5             1             0         2         1
# 1            6            8             0             1         2         0
# 2            7            5             1             0         2         1
#
#    BedroomAbvGr  KitchenAbvGr  TotRmsAbvGrd  Fireplaces  GarageCars  PoolArea  \
# 0             3             1             8           0           2         0
# 1             3             1             6           1           2         0
# 2             3             1             6           1           2         0
#
#    MoSold
# 0       2
# 1       5
# 2       9

# %%
# let explore how this discrete variables affect house price 

for var in discrete_vars:
    sns.catplot(
        x = var,
        y = 'SalePrice',
        data = data,
        kind = 'box', 
        height = 4,
        aspect = 1.5
    )

    sns.stripplot(
        x = var,
        y = 'SalePrice', 
        data = data,
        jitter = True, 
        alpha = 0.3,
        color = 'k' 
    )

    plt.show()

# %% [markdown]
# for most of the discrete numerical variables we see an increase in sales price with increase in quality, overall condition, number of rooms or surface.
#
# For some others like month sold, pool area, fire place etc we do not see any clear relationship between sales
#
# [learn more about strip plots here](https://www.geeksforgeeks.org/stripplot-using-seaborn-in-python/)
#
# [catplot](https://www.geeksforgeeks.org/python-seaborn-catplot/)

# %% [markdown]
# ### Continuous Variables

# %%
cont_vars = [
    var for var in num_vars if var not in discrete_vars and var not in year_vars
]

print('Number of continuous variables ', len(cont_vars))
# Out:
# Number of continuous variables  18

# %%
# cont_vars_count = [
#     var for var in cont_vars data[var].unique()
# ]
# cont_vars_count

# %%
# let deter the type of distribution by plotting histogram

data[cont_vars].hist(bins = 30, figsize=(15, 15))

plt.show()

# %% [markdown]
# A good number of the discrete variables are not normally distributed. Yeo-Johnson transformation and logarithmic transformation will be applied to the variables that are skewed.

# %%
skewed = [
    'BsmtFinSF2', 'LowQualFinSF', 'EnclosedPorch',
    '3SsnPorch', 'ScreenPorch', 'MiscVal'
]

# %%
cont_vars = [
    var for var in cont_vars if var not in skewed
]

# %%
cont_vars
# Out:
# ['LotFrontage',
#  'LotArea',
#  'MasVnrArea',
#  'BsmtFinSF1',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'GarageArea',
#  'WoodDeckSF',
#  'OpenPorchSF']

# %%
# make a copy of our original data
tmp = data.copy()

for var in cont_vars:

    # transform the variable - yeo-johnson
    tmp[var], param = stat.yeojohnson(data[var])


tmp[cont_vars].hist(bins=30, figsize=(15, 15))
plt.show()

# %% [markdown]
# yeo-johnson transformation did not make much difference for both LotFrontage and MasVnrArea. Results for others shows that values seems to be spread more evenly in the range
#
# In the next plot we will compare plots of original and transformed variables

# %%
for var in cont_vars:
    
    plt.figure(figsize=(12, 4))
 

    plt.subplot(1, 2, 1) # has 1 row, 2 columns and it is first plot
    plt.scatter(data[var], np.log(data['SalePrice']))
    plt.ylabel('SalePrice')
    plt.xlabel('Original ' + var)


    plt.subplot(1, 2, 2) # has 1 row, 2 columns and it is second plot
    plt.scatter(tmp[var], np.log(tmp['SalePrice']))
    plt.ylabel('Sale Price')
    plt.xlabel('Transformed ' + var)

    plt.show()

# %% [markdown]
# We would apply logarithmic trandformation to only columns without zeros. We would apply to the following columns
# ....
# ["LotFrontage", "1stFlrSF", "GrLivArea"]
#
# ### Logarithmic transformation

# %%
tmp  = data.copy()

for var in ["LotFrontage", "1stFlrSF", "GrLivArea"]:

    tmp[var] = np.log(data[var])

tmp[["LotFrontage", "1stFlrSF", "GrLivArea"]].hist(bins=30)
plt.show()

# %% [markdown]
# Let's evaluate the relationship between this variales and target variable
# We do a scatter plot of the transformed plot and original variable

# %%
for var in ["LotFrontage", "1stFlrSF", "GrLivArea"]:

    plt.figure(figsize = (12, 4))

    plt.subplot(1, 2, 1)
    plt.scatter(data[var], np.log(data['SalePrice']))
    plt.ylabel('Sale Price')
    plt.xlabel('Original ' + var)

    plt.subplot(1, 2, 2)
    plt.scatter(tmp[var], np.log(data['SalePrice']))
    plt.ylabel('Sale Price')
    plt.xlabel('Transformed ' + var)


    plt.show()

# %% [markdown]
# My observation shows that transformed variables have a better spread than original variable

# %% [markdown]
# ### Skewed Variables

# %%
for var in skewed:

    tmp = data.copy()

    #map value 0 to 0 anyhing else to 1
    tmp[var] = np.where(data[var]==0, 0, 1)

    tmp = tmp.groupby(var)['SalePrice'].agg(['mean', 'std'])

    tmp.plot(
        kind='barh',
        y='mean',
        legend=False,
        xerr='std',
        title='Sale Price',
        color='m'
    )

    plt.show()

# %% [markdown]
# ### Categorical Variables

# %%
print('Number of categorical Variables', len(cat_var))
# Out:
# Number of categorical Variables 44

# %%
data[cat_var].head(3)
# Out:
#   MSZoning Street Alley LotShape LandContour Utilities LotConfig LandSlope  \
# 0       RL   Pave   NaN      Reg         Lvl    AllPub    Inside       Gtl
# 1       RL   Pave   NaN      Reg         Lvl    AllPub       FR2       Gtl
# 2       RL   Pave   NaN      IR1         Lvl    AllPub    Inside       Gtl
#
#   Neighborhood Condition1 Condition2 BldgType HouseStyle RoofStyle RoofMatl  \
# 0      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
# 1      Veenker      Feedr       Norm     1Fam     1Story     Gable  CompShg
# 2      CollgCr       Norm       Norm     1Fam     2Story     Gable  CompShg
#
#   Exterior1st Exterior2nd MasVnrType ExterQual ExterCond Foundation BsmtQual  \
# 0     VinylSd     VinylSd    BrkFace        Gd        TA      PConc       Gd
# 1     MetalSd     MetalSd       None        TA        TA     CBlock       Gd
# 2     VinylSd     VinylSd    BrkFace        Gd        TA      PConc       Gd
#
# ...

# %% [markdown]
# ### Number of labels: cardinality
#
# Let's evaluate the number of labels each categorical variable has

# %%
data[cat_var].nunique().sort_values(ascending=False).plot.bar(
    figsize=(12, 5)
)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Neighborhood has number of cardinality 25.

# %% [markdown]
# ### Quality variables
#
# There are a number of variables that refer to the quality of some aspect of the house, for example the garage, or the fence, or the kitchen. I will replace these categories by numbers increasing with the quality of the place or room.
#
# The mappings can be obtained from the Kaggle Website. One example:
#
# - Ex = Excellent
# - Gd = Good
# - TA = Average/Typical
# - Fa =	Fair
# - Po = Poor

# %%
qual_mappings = {'Po': 1, 
'Fa': 2, 
'TA': 3, 
'Gd': 4, 
'Ex': 5, 
'Missing': 0, 
'NA': 0
}

qual_vars = ['ExterQual', 'ExterCond', 'BsmtQual', 'BsmtCond',
             'HeatingQC', 'KitchenQual', 'FireplaceQu',
             'GarageQual', 'GarageCond',
            ]


for var in qual_vars:
    data[var] = data[var].map(qual_mappings)

# %%
exposure_mappings = {'No': 1, 'Mn': 2, 'Av': 3, 'Gd': 4, 'Missing': 0, 'NA': 0}

var = 'BsmtExposure'

data[var] = data[var].map(exposure_mappings)

# %%
finish_mappings = {'Missing': 0, 'NA': 0, 'Unf': 1, 'LwQ': 2, 'Rec': 3, 'BLQ': 4, 'ALQ': 5, 'GLQ': 6}

finish_vars = ['BsmtFinType1', 'BsmtFinType2']

for var in finish_vars:
    data[var] = data[var].map(finish_mappings)

# %%
garage_mappings = {'Missing': 0, 'NA': 0, 'Unf': 1, 'RFn': 2, 'Fin': 3}


var = 'GarageFinish'

data[var] = data[var].map(garage_mappings)

# %%
qual_vars = qual_vars + finish_vars + ['BsmtExposure','GarageFinish','Fence']

# %%
# We do a plot of the mean sales price based in quality
# of various quality variable


for var in qual_vars:

    sns.catplot(
        x=var,
        y='SalePrice',
        data = data,
        kind='box',
        height=4,
        aspect=1.5
    )

    sns.stripplot(
        x=var, 
        y = 'SalePrice',
        data=data,
        jitter=0.1,
        alpha=0.3,
        color='black'
    )
    plt.show()

# %% [markdown]
# For most of the variables an increase in the variable leads to a corresponding increae in Sales Price

# %%
# we now examine other categorical variables that were not capture in quality variables 

cat_others = [
    var for var in cat_var if var not in qual_vars
]

len(cat_others)
# Out:
# 30

# %% [markdown]
# ### Rare Variables

# %% [markdown]
# Let's go ahead and investigate those labels that are present only in small number of houses ( 1% in this case)

# %%
def analyse_rare_labels(df, var, rare_perc):

    df = df.copy()
    # determine the % of observation per category
    tmp = df.groupby(var)['SalePrice'].count() / len(df)

    return tmp[tmp > rare_perc]

for var in cat_others:
    print(analyse_rare_labels(data, var, 0.01))
    print(end='=========================>')
# Out:
# MSZoning
# FV    0.044521
# RH    0.010959
# RL    0.788356
# RM    0.149315
# Name: SalePrice, dtype: float64
# =========================>Street
# Pave    0.99589
# Name: SalePrice, dtype: float64
# =========================>Alley
# Grvl    0.034247
# Pave    0.028082
# Name: SalePrice, dtype: float64
# =========================>LotShape
# IR1    0.331507
# IR2    0.028082
# Reg    0.633562
# Name: SalePrice, dtype: float64
# =========================>LandContour
# Bnk    0.043151
# HLS    0.034247
# Low    0.024658
# Lvl    0.897945
# Name: SalePrice, dtype: float64
# =========================>Utilities
# AllPub    0.999315
# Name: SalePrice, dtype: float64
# =========================>LotConfig
# Corner     0.180137
# CulDSac    0.064384
# FR2        0.032192
# Inside     0.720548
# Name: SalePrice, dtype: float64
# =========================>LandSlope
# Gtl    0.946575
# Mod    0.044521
# Name: SalePrice, dtype: float64
# =========================>Neighborhood
# ...

# %% [markdown]
# On a final note we do what we did same thing we did for quality variables, a stripplot on a strip plot

# %%
for var in cat_others:

    sns.catplot(
        x=var,
        y='SalePrice',
        data=data,
        kind='box',
        height=4,
        aspect=1.5
    )
    sns.stripplot(
        x=var,
        y='SalePrice',
        data=data,
        jitter=0.1,
        alpha=0.3,
        color='black'
    )
# Out:
# /home/arnold/Desktop/MlOp/env/lib/python3.8/site-packages/seaborn/axisgrid.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(figsize=figsize)

# %% [markdown]
# From the plots above it observed that for each of the categories give median sales price is differs
